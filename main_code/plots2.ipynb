# %%
import numpy as np
import matplotlib.pyplot as plt

ZPVE_xTB = np.loadtxt('ZPVE_xTB_Delta46.txt')
ZPVE_ML = np.loadtxt('ZPVE_ML_Delta46.txt')

plt.plot(ZPVE_xTB,ZPVE_ML,'.')
min_val = 0.00
max_val = 0.05
plt.plot([min_val,max_val],[min_val,max_val],'k-')

# %%
from operator import matmul
R = np.array([[0.3,2,1.3],[4,1,3],[2,9,26]])

L = []

for i in range(3):
     for j in range(3):
          L.extend([R[i,j]]) #hier flatten

print(L)

print(R.flatten())
# Out:
# [0.3, 2.0, 1.3, 4.0, 1.0, 3.0, 2.0, 9.0, 26.0]
# [ 0.3  2.   1.3  4.   1.   3.   2.   9.  26. ]
