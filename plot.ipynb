# %%
import matplotlib.pyplot as plt
import numpy as np

freq_ML = np.genfromtxt('plots/freq_ML')
freq_xTB = np.genfromtxt('plots/freq_xTB')

plt.plot(freq_xTB[0:3],freq_ML[0:3],'.',label = r'H$_\mathrm{2}$')
plt.plot(freq_xTB[3:8],freq_ML[3:8],'.',label = r'N$_\mathrm{2}$')
plt.plot(freq_xTB[8:13],freq_ML[8:13],'.',label = r'O$_\mathrm{2}$')
plt.plot(freq_xTB[13:18],freq_ML[13:18],'.',label = r'F$_\mathrm{2}$')
plt.plot(freq_xTB[18:23],freq_ML[18:23],'.',label = r'CO')
plt.plot(freq_xTB[23:28],freq_ML[23:28],'.',label = r'HF')
plt.plot(freq_xTB[28:],freq_ML[28:],'.',label = r'H$_\mathrm{2}$O')



plt.legend()
plt.plot([0,10000],[0,10000],'k')

plt.xlim([0,5000])
plt.ylim([0,5000])

plt.ylabel(r'$\tilde{\nu}_\mathrm{ML}~[\mathrm{cm^{-1}}]$')
plt.xlabel(r'$\tilde{\nu}_\mathrm{xTB}~[\mathrm{cm^{-1}}]$')

plt.savefig('plots/Diatomic_ML_model.svg')
plt.savefig('plots/Diatomic_ML_model.png')
plt.savefig('plots/Diatomic_ML_model.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

freq_ML = np.genfromtxt('plots/freq_ML')
freq_xTB = np.genfromtxt('plots/freq_xTB')
freq_ML_norm = freq_ML/freq_xTB

plt.plot(freq_xTB[0:],(freq_ML_norm[0:]),'.',label = r'lorem',)

plt.plot([0,20000],[1,1],'k',linewidth = 1)

plt.xlim([0,12000])
#plt.ylim([1,1.2])
plt.yscale('log')

plt.ylabel(r'$\tilde{\nu}_\mathrm{ML}^\mathrm{norm}~[\mathrm{cm^{-1}}]$')
plt.xlabel(r'$\tilde{\nu}_\mathrm{xTB}~[\mathrm{cm^{-1}}]$')

plt.savefig('plots/ML_model_multimol_ite_rnd_norm.svg')
plt.savefig('plots/ML_model_multimol_ite_rnd_norm.png')
plt.savefig('plots/ML_model_multimol_ite_rnd_norm.eps')
plt.show()

# %%
#path = 'tests/ML_single_mol/plots_log_etc/plots/'
#path_2 ='tests/ML_multimolecule_various_rnd_states/plots2/'
path = 'plots/Data_8/'
#path_2 ='plots/frequenzen/permuted_Xfeature_200F_alldiag_allnondiag/'
import numpy as np

# %%
import matplotlib.pyplot as plt

plt.style.use('rwth_colors.mplstyle')

freq_ML = np.genfromtxt(f'{path}wn_ML_perm_m')*0.002859144166
freq_xTB = np.genfromtxt(f'{path}wn_xTB_perm_m')*0.002859144166

#freq_ML_small = np.genfromtxt(f'{path_2}freq_ML')
#freq_xTB_small = np.genfromtxt(f'{path_2}freq_xTB')

fontsize =24
#freq_ML_norm = freq_ML/freq_xTB

plt.plot(freq_xTB[0:],freq_ML[:],'.',label = r'ETR-Case-Perm',)
#plt.plot(freq_xTB_small[0:],freq_ML_small[0:],'.',label = r'Singlemolecule Models')

plt.legend(fontsize = fontsize)
box_width = 70
plt.plot([0,box_width],[0,box_width],'k',linewidth = 1)

plt.xlim([0,box_width])
plt.ylim([0,box_width])

plt.ylabel(r'$\tilde{\nu}_\mathrm{ML}~[\mathrm{kcal \cdot mol^{-1}}]$',fontsize = fontsize)
plt.xlabel(r'$\tilde{\nu}_\mathrm{xTB}~[\mathrm{kcal \cdot mol^{-1}}]$',fontsize = fontsize)

file_name = 'WN_xTB_vs_ML'

plt.savefig(f'{path}{file_name}.svg')
plt.savefig(f'{path}{file_name}.png')
plt.savefig(f'{path}{file_name}.eps')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

freq_ML = np.genfromtxt(f'{path}freq_ML')
freq_xTB = np.genfromtxt(f'{path}freq_xTB')

#freq_ML_small = np.genfromtxt(f'{path_2}freq_ML')
#freq_xTB_small = np.genfromtxt(f'{path_2}freq_xTB')

plt.style.use('rwth_colors.mplstyle')
n_est = [10,25,50,100,150,200,300]
for i in range(7):
    plt.plot(freq_xTB[i*309:(i+1)*309],freq_ML[i*309:(i+1)*309],'.',label = n_est[i])
#plt.plot(freq_xTB_small[0:],freq_ML_small,'.',label = r'multi',color = 'orange')

plt.plot([0,1e5],[0,1e5],'k',linewidth = 1)

plt.legend()
plt.xlim([9e1,6e4])
plt.ylim([9e1,6e4])

plt.xscale('log')
plt.yscale('log')

plt.ylabel(r'$\tilde{\nu}_\mathrm{ML}~[\mathrm{cm^{-1}}]$')
plt.xlabel(r'$\tilde{\nu}_\mathrm{xTB}~[\mathrm{cm^{-1}}]$')

plt.savefig(f'{path}ML_model_multimol_and_single_log.svg')
plt.savefig(f'{path}ML_model_multimol_and_single_log.png')
plt.savefig(f'{path}ML_model_multimol_and_single_log.eps')
plt.show()
# Out:
# Running cells with 'Python 3.8.10 ('venv_hessian_ml')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/gfeldmann/Venv/venv_hessian_ml/bin/python3 -m pip install ipykernel -U --force-reinstall'

# %%
import matplotlib.pyplot as plt
import numpy as np

freq_ML = np.genfromtxt('plots/freq_ML')
freq_xTB = np.genfromtxt('plots/freq_xTB')

plt.plot(freq_xTB[0:],freq_ML[0:],'.',label = r'H$_\mathrm{2}$O')

plt.legend()
plt.plot([0,20000],[0,20000],'k')

plt.xlim([0,5000])
plt.ylim([0,5000])

plt.ylabel(r'$\tilde{\nu}_\mathrm{ML}~[\mathrm{cm^{-1}}]$')
plt.xlabel(r'$\tilde{\nu}_\mathrm{xTB}~[\mathrm{cm^{-1}}]$')

plt.savefig('plots/Water_ML_model_cut.svg')
plt.savefig('plots/Water_ML_model_cut.png')
plt.savefig('plots/Water_ML_model_cut.eps')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/gfeldmann/Documents/GitLab/hessian_ml/plot.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/gfeldmann/Documents/GitLab/hessian_ml/plot.ipynb#ch0000005?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/gfeldmann/Documents/GitLab/hessian_ml/plot.ipynb#ch0000005?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/home/gfeldmann/Documents/GitLab/hessian_ml/plot.ipynb#ch0000005?line=3'>4</a> freq_ML = np.genfromtxt('plots/freq_ML')
#       <a href='vscode-notebook-cell:/home/gfeldmann/Documents/GitLab/hessian_ml/plot.ipynb#ch0000005?line=4'>5</a> freq_xTB = np.genfromtxt('plots/freq_xTB')
# ...

# %%
n_est = []
for j in [10,25,50,100,150,200,300]:
    for i in range(10):
        n_est.append(j)

# %%
#n_est = np.genfromtxt(f'{path}n_est',)
rscorediag = np.genfromtxt(f'{path}rscore_diag')
rscorenondiag = np.genfromtxt(f'{path}rscore_nondiag')

print(n_est)

r_mean_nd = np.zeros(7)
r_mean_d = np.zeros(7)
n = np.zeros(7)
N_rnd = 10
for i in range(0,len(n_est),N_rnd):
    r_mean_nd[i//N_rnd] = np.mean(rscorenondiag[i:i+N_rnd])
    r_mean_d[i//N_rnd] = np.mean(rscorediag[i:i+N_rnd])
    n[i//N_rnd] = n_est[i]
    

#plt.plot(n,r_mean_d,'.',label = r'multi',color = 'orange')

plt.plot(n,r_mean_nd,'.',label = r'multi',color = 'blue')
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]

# %%
import matplotlib.pyplot as plt
import numpy as np

col_name = [r'$pos$',r'$R_\mathrm{AB}$', r'$CN$', r'$CN^\mathrm{ext}$', r'$\mu_\mathrm{x}$', r'$\mu_\mathrm{y}$', r'$\mu_\mathrm{z}$', r'$\mu_\mathrm{x}^\mathrm{ext}$', r'$\mu_\mathrm{y}^\mathrm{ext}$', r'$\mu_\mathrm{z}^\mathrm{ext}$',
 r'$\mu_\mathrm{x,p}^\mathrm{ext}$',  r'$\mu_\mathrm{y,p}^\mathrm{ext}$',  r'$\mu_\mathrm{z,p}^\mathrm{ext}$', r'$\theta_\mathrm{x}$', r'$\theta_\mathrm{y}$', r'$\theta_\mathrm{z}$',
  r'$\theta_\mathrm{x}^\mathrm{ext}$', r'$\theta_\mathrm{y}^\mathrm{ext}$', r'$\theta_\mathrm{z}^\mathrm{ext}$',
  r'$\theta_\mathrm{x,Z}^\mathrm{ext}$', r'$\theta_\mathrm{y,Z}^\mathrm{ext}$', r'$\theta_\mathrm{z,Z}^\mathrm{ext}$', r'$\theta_\mathrm{x,p}^\mathrm{ext}$', r'$\theta_\mathrm{y,p}^\mathrm{ext}$', r'$\theta_\mathrm{z,p}^\mathrm{ext}$',
   'response (a.u.)_A', r'$E_\mathrm{gap}$', r'$\mu_\mathrm{pot}$', r'$\epsilon_\mathrm{HOAO}$',
 r'$\epsilon_\mathrm{LUAO}$', r'$E_\mathrm{rep}$', r'$E_\mathrm{EHT}$', r'$E_\mathrm{disp}^{2}$', r'$E_\mathrm{disp}^{3}$', r'$E_\mathrm{IES + IXC}$', r'$E_\mathrm{AES}$', r'$E_\mathrm{tot}$', r'$E_\mathrm{AXC}$', r'$\mu_\mathrm{pot}^\mathrm{ext}$', r'$E_\mathrm{gap}^{\mathrm{ext}$',
  r'$\epsilon_\mathrm{HOAO}^\mathrm{ext}$', r'$\epsilon_\mathrm{LUAO}^\mathrm{ext}$']

importances_path = 'plots/frequenzen/importances_non_diag_22'

N_features = 40
importances = np.genfromtxt(importances_path)

ticks = np.array(range(N_features+1))
fig ,ax = plt.subplots()

ax.bar(ticks[0] ,importances[0],alpha=1.0, width=0.15, label = 'Rab')
ax.bar(ticks[1:N_features+1]-0.3 ,importances[1:N_features+1],alpha=1.0, width=0.15, label = 'A')
ax.bar(ticks[1:N_features+1]-0.15,importances[N_features+1:2*N_features+1],alpha=1.0, width=0.15, label = 'B')#'atom A')
ax.bar(ticks[1:N_features+1],importances[2*N_features+1:3*N_features+1],alpha=1.0, width=0.15, label = 'arithmetic mean')#'atom B')
ax.bar(ticks[1:N_features+1]+0.15,importances[3*N_features+1:4*N_features+1],alpha=1.0, width=0.15, label = 'product')#'arithmetic mean')
ax.bar(ticks[1:N_features+1]+0.3 ,importances[4*N_features+1:5*N_features+1],alpha=1.0, width=0.15, label = 'absolute difference')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Features')
ax.set_ylabel('R² coefficient')
ax.set_xticks(ticks)
ax.set_xticklabels(col_name[:N_features+1],rotation=90)
plt.gcf().subplots_adjust(bottom=0.45)
fig.set_figwidth(15)

#plt.savefig(f'')
#plt.savefig(f'')
# Out:
# Error in callback <function flush_figures at 0x000001A0DA2DFC10> (for post_execute):

# %%
import numpy as np
import matplotlib.pyplot as plt

fontsize = 18

plt.rcParams.update({'errorbar.capsize': 5})

plt.style.use('rwth_colors.mplstyle')
genname = [f'plots/MSE_sigma/MSE_d_indexed_m_',f'plots/MSE_sigma/MSE_nd_indexed_m_']
labels = ['homonuclear','heteronuclear']
for i in [0,2,1]:
    err = []
    mse_d = []
    rnd_states = [0.0,0.5,1,1.5,2,2.5]
    for rnd_factor in rnd_states:
        if i == 2:
            print('s')
        else:
            mse_rnd =  np.genfromtxt(f'{genname[i]}{rnd_factor}')
            mse_d.append(mse_rnd.mean())
            err.append(np.std(mse_rnd))

    if i == 2:
        plt.errorbar(1.0,100)
    else:
        plt.errorbar(np.array(rnd_states),mse_d,err,fmt = 'x-',label = labels[i],capsize=5)
        
plt.ylim([-0.05,1])
plt.ylabel('MSE',fontsize = fontsize)
plt.xlabel(r'$\sigma$',fontsize = fontsize)
plt.legend(fontsize = fontsize)
save_name_ ='plots/MSE_vs_sigma'

plt.savefig(f'{save_name_}.svg')
plt.savefig(f'{save_name_}.eps')
plt.savefig(f'{save_name_}.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# s
# s
# s
# s
# s
# s

# %%
import matplotlib.pyplot as plt
import math
plt.style.use('rwth_colors.mplstyle')
def f(x,SD,mean):
    pi = math.pi
    #print(pi)
    #y = np.zeros(len(x))
    y = 1.0/(SD*math.sqrt(2*pi))*np.exp(-0.5*((x-mean)/SD)**2)
    return y
list_plot = []
fig, ax = plt.subplots()
ax.spines['left'].set_visible(False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(True)
ax.spines["right"].set_position(("data", 0))
#ax.yaxis.set_ticks_position('right')
#plt.tick_params(axis='y', which='both', labelleft='off', labelright='on')
ax.yaxis.tick_right()
#ax.yaxis.set_ticks_position('both')
print(ax)

Delta_delta_xtb = Delta_xtb - Delta_DFT
Delta_delta_DFT = Delta_DFT - Delta_DFT
for element in [Delta_delta_DFT,Delta_delta_xtb]:
    array_xtb = np.array(element)

    MD = sum(abs(array_xtb.mean()-array_xtb)/len(array_xtb))
    
    dy2 = sum((array_xtb-array_xtb.mean())**2)
    SD = np.sqrt(dy2/len(array_xtb))
    SD = SD
    x = np.linspace(-20,15,200)
    print(SD)
    #print(x)
    mean = array_xtb.mean()
    print(mean)
    y = f(x,SD,mean)
    pl, = ax.plot(x,y)
    list_plot.append(pl)
    print(list_plot)

# %%
for csv in ['best_gpr0.csv',
'best_gpr1.csv','best_gpr2.csv','best_gpr3.csv','best_rfr0.csv','best_extra0.csv']:
    df_ml = pd.read_csv(csv)
#print(df_ml)d.read_csv(csv)
    df_ml = df_ml.drop('Unnamed: 0',axis=1)

    Delta_ml = df_ml['ML'].to_numpy()
#Delta_ml = Delta_ml[155:]
    Delta_ml = Delta_ml - Delta_ml[reference]
    Delta_ml = conv.au2kcal(Delta_ml)
    Delta_delta_ml = Delta_ml - Delta_DFT
    array_xtb = np.array(Delta_delta_ml)

    MD = sum(abs(array_xtb.mean()-array_xtb)/len(array_xtb))
    
    dy2 = sum((array_xtb-array_xtb.mean())**2)
    SD = np.sqrt(dy2/len(array_xtb))
    SD = SD
    x = np.linspace(-20,20,200)
    #print(MD)
    #print(x)
    mean = array_xtb.mean()
    print(mean)
    y = f(x,SD,mean)
    pl, = ax.plot(x,y)
    list_plot.append(pl)
#list_plot[0].set_label('B97-3c')
list_plot[1].set_label('GFN2-xTB')
#list_plot[2].set_label(r'GFN2-xTB + Ridge Regression($\alpha = 10⁴$)')
#list_plot[3].set_label(r'GFN2-xTB + Linear Regression')
list_plot[2].set_label(r'Matérn ($\nu =0.5,\sigma =100.0$)')
list_plot[3].set_label(r'Matérn ($\nu =1.5,\sigma =100.0$)')
list_plot[4].set_label(r'Matérn ($\nu =2.5,\sigma =100.0$)')
list_plot[5].set_label(r'RBF ($\sigma =100.0$)')
list_plot[6].set_label(r'Random Forrest')
list_plot[7].set_label(r'Extra Trees')

plt.xlabel(r'Distribution of $\Delta\Delta E_{conf}$ [kcal/mol]' )
plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, ha="left")
plt.legend(loc=(0.65,0.55),fontsize=14)
plt.savefig('error_distribution_maltose_ml.png')

# %%
import numpy as np
print(np.array([1,3,4]))
# Out:
# [1 3 4]

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
import numpy as np
from scipy import linalg
from operator import matmul

plt.style.use('rwth_colors.mplstyle')

def rot_Z(alpha):
    R = np.array([[np.cos(alpha), -np.sin(alpha), 0],
                   [np.sin(alpha),  np.cos(alpha), 0],
                   [0,          0,                 1]])
    return R

def rot_X(alpha):
    
    R = np.array([[1,             0,              0],
                   [0, np.cos(alpha), -np.sin(alpha)],
                   [0, np.sin(alpha), np.cos(alpha)]])
    return R 


def angle_two_vec(a,b):
    if linalg.norm(a) == 0. or linalg.norm(b) == 0.:
            cosangle = 0
    else:
        cosangle = matmul(a,b)/linalg.norm(a)/linalg.norm(b)
    
    angle = np.arccos(np.clip(cosangle,-1,1))
    return angle

ax = plt.figure().add_subplot(projection='3d')

x = np.array([0,0,0])
y = np.array([0,0,0])
z = np.array([0,0,0])



u = np.array([1,0,0])
v = np.array([0,1,0])
w = np.array([0,0,1])


a = np.linspace(0,np.pi*2,2001)

c_y = np.cos(a)
c_x = np.sin(a)
c_z = a*0

c = np.array([c_x,c_y,c_z]).T

axes = np.array([u,v,w])

dipm = np.array([0.3,0.2,-0.2]) * linalg.norm(np.array([0.3,0.2,-0.2]))


vec_z = np.array([-0.33,-0.31,0.37]) * linalg.norm(np.array([-0.33,-0.31,0.37]))

vec_x = np.cross(dipm,vec_z)


L1 = np.cross(vec_z,axes[2])
L1 = linalg.norm(L1)**-1*L1

L2 = np.cross(axes[2],vec_z)
L2 = linalg.norm(L2)**-1*L2

LL = np.cross(vec_z,axes[2])

alpha = angle_two_vec(LL,axes[0])
beta = angle_two_vec(vec_z,axes[2])
gamma = angle_two_vec(LL,vec_x)

#Find right rotation angle
if linalg.det(np.array([axes[0],axes[2],LL])) < 0.:
    alpha = 2*np.pi - alpha

if linalg.det(np.array([LL,vec_x,vec_z])) > 0.:
    gamma = 2*np.pi - gamma

R1 = rot_Z(gamma)
R2 = rot_X(beta)
R3 = rot_Z(alpha)

R = np.matmul(np.matmul(R1,R2),R3)

axes_rot = np.matmul(np.transpose(R),axes)

for i in range(len(c)):
    c[i] = np.matmul(np.transpose(R),c[i])
    
c=c.T

ax.quiver(x,y,z,axes[0],axes[1],axes[2],color = 'k',arrow_length_ratio=0.15)



ax.quiver(x,y,z,axes_rot[0],axes_rot[1],axes_rot[2],color = 'b',arrow_length_ratio=0.15)

print(axes_rot[0],axes[2])

ax.quiver(x,y,z,L1[0],L1[1],L1[2],color = 'red',arrow_length_ratio=0.0)
ax.quiver(x,y,z,L2[0],L2[1],L2[2],color = 'red',arrow_length_ratio=0.0)

L1 = L1*1.3
L2 = L2*1.2
ax.text(L1[0],L1[1],L1[2],r'$\mathrm{L_b}$',color = 'r')
ax.text(L2[0],L2[1],L2[2],r'$\mathrm{L_a}$',color = 'r')

ax.scatter(c_x,c_y,c_z,color = 'k',s = 0.1)
ax.scatter(c[0],c[1],c[2],color = 'b',s = 0.1)

ax_lim = 1.2

ax.set_xlim3d(-ax_lim, ax_lim)
ax.set_ylim3d(-ax_lim, ax_lim)
ax.set_zlim3d(-ax_lim, ax_lim)


ax.text(1.1, 0, 0, "x", color='k')
ax.text(0, 1.1, 0, "y", color='k')
ax.text(0, 0, 1.1, "z", color='k')
dist = 1.1 
axes_rot = axes_rot * dist

ax.text(axes_rot[0][0]*1.1,axes_rot[1][0]*1.1,axes_rot[2][0],r"x'",color = 'blue')
ax.text(axes_rot[0][1],axes_rot[1][1],axes_rot[2][1],r"y'",color = 'blue')
ax.text(axes_rot[0][2],axes_rot[1][2],axes_rot[2][2],r"z'",color = 'blue')




ax.set_axis_off()

plt.savefig('EulerAngle.svg')
plt.savefig('EulerAngle.eps')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Fira Sans
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Fira Sans
# [ 0.22291129  0.7948562  -0.56437061] [0 0 1]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
