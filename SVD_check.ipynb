# %%
import numpy as np
class Parent1:
    def __init__(self,id) -> None:
        self.id = id
        self.id1 = None
        self.idrnd = np.random.random()
        pass 

    def idimp(self,id):
        self.id = id
        return

    def idimp1(self,id):
        self.id1 = id
        return 


class Child1(Parent1):
    def __init__(self,id1) -> None:
        Parent1.__init__(Parent1,1)
        Parent1.id1 = id1


class Child2(Parent1):
    def __init__(self):
        Parent1.__init__(Parent1,2)



child1 = Child1(3)

child2 = Child2
# Out:
# 0.7494533321940359
# 0.7494533321940359

# %%
list1 = [[0,1],[0,3],[0,3]]

list2 = [[0,1],[0,3],[0,3]]

list2.extend(list1)

print(list2)
# Out:
# [[0, 1], [0, 3], [0, 3], [0, 1], [0, 3], [0, 3]]
